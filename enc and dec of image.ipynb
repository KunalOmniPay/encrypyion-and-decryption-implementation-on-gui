# %%
from tkinter import *
from tkinter import filedialog
from tkinter.filedialog import askopenfilename
from PIL import ImageTk, Image

# %%
print("hello")
# Out:
# hello

# %%
from tkinter import *
import tkinter
from tkinter import filedialog
from tkinter.filedialog import askopenfilename
from PIL import ImageTk, Image
from Crypto.Cipher import AES
from Crypto import Random
key = Random.new().read(AES.block_size)
i = Random.new().read(AES.block_size)
global root
root=Tk()
#function for browsing image
def browse():
    global a
    a=filedialog.askopenfilename()
    img = ImageTk.PhotoImage(Image.open(a)) 
    E1 = Label(root,text=a,width=100).grid(row=2,column=1)
    canvas = tkinter.Canvas(root, width =300, height = 150)
    canvas.image=img
    canvas.create_image(200,100, image=img)   
    canvas.grid(row=0,column=1)
#function for encrypting image    
def encrypt():
    canvas1 = tkinter.Canvas(root, width =300, height = 150) 
    canvas1.grid(row=0,column=1)
    inputfile = open(a,"rb")
    inputdata = input_file.read()
    input_file.close()
    k = AES.new(key, AES.MODE_CFB, ia)
    global enc_data
    enc = k.encrypt(inputdata)
    E1 = Label(root,text= enc,width=100).grid(row=5,column=1)
def decrypt():
#function for decrypting image
    E1 = Label(root,width=100,height=500).grid(row=5,column=1)
    
    cfb_decipher = AES.new(key, AES.MODE_CFB, iv)
    plain_data = cfb_decipher.decrypt(enc_data)
    img = ImageTk.PhotoImage(Image.open(a)) 
    E1 = Label(root,text=a,width=100).grid(row=2,column=1)
    canvas = tkinter.Canvas(root, width =300, height = 150)
    canvas.image=img
    canvas.create_image(200,100, image=img)   
    canvas.grid(row=0,column=1)
    
b1=Button(root,text="Browse image",command=browse).grid(row=2,column=2)
b2=Button(root,text="encrypt image",command=encrypt).grid(row=4,column=1)
b3=Button(root,text="decrypt image",command =decrypt).grid(row=4,column=4)
root.mainloop()

# %%
from tkinter import *

canvas_width = 300
canvas_height =300

master = Tk()
def bro():
    a=filedialog.askopenfilename()
    canvas = Canvas(master, width = 500, height = 500)  
    canvas.grid(row=6,column=1)
    img = PhotoImage(file=a)  
    canvas.create_image(200,100, anchor=NW, image=img)
bro()
mainloop()

# %%
from tkinter import *
import subprocess as sub
p = sub.Popen('D:\\py.py',stdout=sub.PIPE,stderr=sub.PIPE)
output = p.communicate()

root = tkinter.Tk()
text = Text(root)
text.pack()
text.insert(END, output)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-c13ae8706901> in <module>()
#       1 from tkinter import *
#       2 import subprocess as sub
# ----> 3 p = sub.Popen('D:\\py.py',stdout=sub.PIPE,stderr=sub.PIPE)
#       4 output = p.communicate()
#       5
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ...

# %%
from Crypto.Cipher import AES
from Crypto import Random
key = Random.new().read(AES.block_size)
iv = Random.new().read(AES.block_size)

# %%
a="D:\\data science\\bush.jpg"
input_file = open(a,"rb")
input_data = input_file.read()
input_file.close()

cfb_cipher = AES.new(key, AES.MODE_CFB, iv)
enc_data = cfb_cipher.encrypt(input_data)
enc_data
# Out:
# b'[t\xa8\xe2\x87\x80\xd9S\x91\x1f\xa9^\xb4\x1a5\x19Y\xd0N\xc7\x13\x12\xf2\xbc\xdd\x0e\xc1b<\x8b\xef\xe6\x8e0\xc2h\xb6\xfb[\xae\xa6\x12\xb1\xdf\xb2\x8c\x04\xb8C\xf7\x82\xdc\x93\xef\xd0\xfelpy\xc6q[J\xb0\xe0\xcc\xc3\x88q\xcd\xfb\xd2\x7f\r2\xbbU\x91qK\n\x85\x8d\x1d\xfaIl\x7fuMe\xff\x9bM\x98\xd3n\xbd\xd4#\n\xb5Z7\x97r\x84u\xa95\x01\xaa\x8c\xdf\x83(V\xaeb\xc5\xe6\x11s\x96S\xfa\xc4\xdb\xe1\x1b69\x86_7v\xdc\x89=.Z\xeb\xdb\xceQ\xe4\xeaY\xb8\xd7S\xe4\xe4\x89\xae\xbcQ\xb2\xd7F\xefY\xd6\x8aKjy\xe4\xf4_@\xf4\x1e\x82\x8fk/\x07\xaf\xf9V_\xdac2*\x9a\r\x14J\xde\xc0\xe9a\x1a\x0b%U\x199\x1b\xc0\xcb\x87\xce\x00\x01l,F\xb8\x93\xd9H\xd96\xd2\xc3}\x88\x87\n\xb3\x08V\xc8G\x0c$\xe7\x86\xfd\xc1EiU\xe7\xaf\xecZ\x86B\xa6v\xe6\xcb6\xe1 q\xa7^{\x89\x9dCL\xd9\x10bX0Np\xf63\xdeKb\xb6\xaf\x8dC\xa3\xf9\xad\x941j\x97\x1f\xe7\x9fN\xb2\x86\x9b!\x8f\x8c\xcc\xef\x8c\xe1\xf9x\x0e}u\x91\x80\xd7l\xfaCB\xbc\x1a\xb4_\x02\x16B\xf5\xa4\xdd\x19\xf5VX\xe1;\x1a\x18*\xd6C}S\x03\xba\x02\xc9x\xd7\xe5m\x98\xa6B\xfc\x11Wl\xf9\x928\x98\
# ...

# %%
from tkinter import *

def printSomething():
    print ("Hey whatsup bro, i am doing something very interresting.")

root = Tk()

button = Button(root, text="Print Me", command=printSomething)
button.pack()

root.mainloop()
# Out:
# Hey whatsup bro, i am doing something very interresting.

# %%
from tkinter import *
import platform

def printSomething():
    
    label = Label(root,text= platform.uname())
    label.pack() 

root = Tk()

button = Button(root, text="Print Me", command=printSomething) 
button.pack()

root.mainloop()
